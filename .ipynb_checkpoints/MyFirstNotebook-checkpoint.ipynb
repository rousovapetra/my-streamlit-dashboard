# %% [markdown]
# # První hodina

# %% [markdown]
# projít prezentaci a zaregistrovat se na domácí úkoly
# - instalace

# %%
name = "Péťa"
print(f"Ahoj {name}")
# Out:
# Ahoj Péťa

# %%
name = "Petra"

# %%
print(name)
# Out:
# Petra

# %%
x = 3
333 * x
# Out:
# 999
